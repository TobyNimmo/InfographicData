# %%
# Import pandas libary abbreviated as pd
import pandas as pd
# Stop pandas from abbreviating tables to fit in the notebook
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
# Display graphs in the notebook
# %matplotlib inline

# %%
# read in our csv file, and automatically change missing values into NaN
rates = pd.read_csv('Rate of productivity growth.csv', na_values = ['.',' '])
# Use the head function to see the first few rows
rates.head(20).set_index('GVA per workforce job estimates for London in 2016').sort_values('Growth Rate 16-15',0,False)
# Out:
#                                                             2016  \
# GVA per workforce job estimates for London in 2016
# Mining and quarrying                                 54133.33333
# Real estate activities                              488586.87260
# Wholesale and retail trade; repair of motor veh...   49254.53113
# Information and communication                        92522.03390
# Other service activities                             53692.30769
# Construction                                         63163.01703
# Administrative and support service activities        36464.83180
# Professional; scientific and technical activities    60804.14887
# Arts; entertainment and recreation                   40678.96679
# Water supply; sewerage and waste management          91402.98507
# Public administration and defence                    54096.70330
# Accommodation and food service activities            29334.95146
# Human health and social work activities              35756.27240
# ...
